# %%
# import csv 

# with open("collage_data.csv", "r", newline="", encoding="UTF-8") as file:
#     x = csv.reader(file)
#     data = list(x)

# new_data = []
# new_data.append(data[0])
# for i in data[1:]:
#     new_data.append([int(i[0]),i[1],int(i[2].replace(",","")),int(i[3].replace(",","")),int(i[4]) if i[4] != "-" else ""])

# print(*new_data,sep="\n")

# with open("collage_data.csv", "w", newline="") as file:
#     f = csv.writer(file)
#     f.writerows(new_data)


import pandas as pd
data = pd.read_csv("collage_data.csv")

data.sort_values("Mid-Career Pay",ascending=False)
# Out:
#      Rank                                             Major  Early Career Pay  \
# 0       1                             Petroleum Engineering             93200
# 1       2      Operations Research & Industrial Engineering             84800
# 2       3  Electrical Engineering & Computer Science (EECS)            108500
# 3       4                                Interaction Design             68300
# 4       5                                 Public Accounting             59800
# ..    ...                                               ...               ...
# 822   823                                 Outdoor Education             37400
# 823   824                         Early Childhood Education             36100
# 824   825                                     Mental Health             36900
# 825   826                                 Medical Assisting             36000
# 826   827                                     Metalsmithing             40000
#
# ...
